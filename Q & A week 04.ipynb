# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("Telco.xlsx")
data.head()
# Out:
# C:\Users\sreel\anaconda3\ANACONDA\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# ...

# %% [markdown]
# # 1.Compare churn count with respect to gender.

# %%
sns.countplot(data['gender'],hue=data['Churn'],data=data)
plt.title('Churn count vs Gender', fontweight='bold', fontsize=10)
plt.grid()
# Out:
# C:\Users\sreel\anaconda3\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 2.Find out how many female senior citizens there in the dataset

# %%
plt.figure(figsize=(8,4))
f=data[data['gender']=='Female']
s=f[f['SeniorCitizen']==1.0]
a=s[['gender','SeniorCitizen']]
g=len(a['SeniorCitizen'])
sns.countplot(x='gender',data=a)
plt.grid()

# %%
g=len(a['SeniorCitizen'])
g
# Out:
# 568

# %% [markdown]
# # 3.Compare 'tenure' with 'Total Charges'

# %%
plt.figure(figsize=(10,10))
plt.scatter(data['tenure'],data['TotalCharges'])
plt.title('Tenure vs Total Charges', fontsize=15)
plt.xlabel('Tenure')
plt.ylabel('Total Charges')
# Out:
# Text(0, 0.5, 'Total Charges')

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen

# %%
senior=data[data['SeniorCitizen']==1.0]
senior
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male            1.0      No         No     1.0
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 31    4929-XIHVW    Male            1.0     Yes         No     2.0
# 34    3413-BMNZE    Male            1.0      No         No     1.0
# 50    8012-SOUDQ  Female            1.0      No         No    43.0
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7029  2235-DWLJU  Female            1.0      No         No     6.0
# 7031  3605-JISKB    Male            1.0     Yes         No    55.0
# 7032  6894-LFHLY    Male            1.0      No         No     1.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=senior['Contract'])
plt.title('Contract preference of Senior Citizen', fontweight='bold', fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# # 5. Comment on your finds on Payment Method

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=data['PaymentMethod'])
plt.title('Prefered payment method', fontweight='bold', fontsize=18)
plt.xticks()
plt.grid()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=data['PaymentMethod'], hue=data['Contract'])
plt.title('Prefered payment method; contractwise', fontweight='bold', fontsize=20)
plt.xticks()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=data['PaymentMethod'], hue=data['PaperlessBilling'])
plt.title('Prefered payment method Vs billing', fontweight='bold', fontsize=20)
plt.xticks()
plt.grid()
plt.show()
